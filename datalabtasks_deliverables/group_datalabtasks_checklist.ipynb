# %% [markdown]
# # Block D - Group Deliverables Checklist
#
# > **Individual tasks** (Task 4.1, 5, 10, 11, 12) are tracked in your own learning log.
# >
# > For every group task below, each team member must also add **individual evidence links** in their own learning log section C.

# %% [markdown]
# ---
# # Task 2 - Technical Collaboration | ILO 9.2A | 2 pts
#
# ## What to do
# The student demonstrates competency in the use of **virtual environments**, **package managers** and **version control** tools for collaborating on group data science projects.
#
# - &check; Everyone works on separate feature branches
# - &check; All code merged to `main` via pull requests
# - &cross; Everyone has reviewed and approved at least one pull request
# - &check; Poetry `.toml` and `.lock` files present in the repo root
#
# ## Evidence (per person in learning log under ILO 9.2A)
# | What | Where |
# |------|-------|
# | Link to a pull request **you made** | GitHub PR URL |
# | Link to a pull request **you reviewed** | GitHub PR URL |
# | Link to the Poetry `.toml` file | GitHub file URL |
# | Link to the Poetry `.lock` file | GitHub file URL |

# %% [markdown]
# ---
# # Task 4.2 - Legal Compliance Report | ILO 3.3B | 3 pts
# **Must pass: ILO 3.3 total > 55% (min. 6/10 pts combined with Task 4.1)**
#
# ## What to do
# The team **collaboratively** identifies and motivates the level of risk associated with the developed AI system and the applicable legal requirements using relevant legal frameworks.
#
# - &cross; Risk category of the **built system** identified and justified as a team
# - &cross; AI Act obligations documented and reasoned (include + exclude)
# - &cross; GDPR chapters 2, 3 and 4 covered with compliance evidence
# - &cross; Digital Services Act (DSA) and industry-specific regulations covered
# - &cross; Evidence of how the system actually complies documented
# - &cross; `FinalReportILO3_Template` completed and submitted
#
# ## Evidence (per person in learning log under ILO 3.3B)
# | What | Where |
# |------|-------|
# | Link to the completed group legal compliance report | GitHub / Brightspace |
# | Brief description of how you solved this task | Learning log text |

# %% [markdown]
# ---
# # Task 6 - Group Project Proposal | ILO 4.2B | 3 pts
# **Must pass: ILO 4.2 total > 55% (min. 6/10 pts combined with Task 5 and Task 14)**
#
# ## What to do
# The team combines individual proposals into a **group project proposal** including a project planning. The proposal demonstrates understanding of the business context and aligns with project requirements.
#
# - &check; All individual proposals reviewed and strongest elements combined
# - &check; Shared problem statement and project objective defined
# - &cross; Business value explained
# - &cross; Datasets identified and justified
# - &cross; Methodology described (data collection, preprocessing, modelling, evaluation)
# - &cross; Project timeline included
# - &cross; Under 5000 words
# - &cross; Updated based on mentor/stakeholder feedback
# - &cross; Written using `ProjectProposal_Template`
#
# ## Evidence (per person in learning log under ILO 4.2B)
# | What | Where |
# |------|-------|
# | Link to the group project proposal | GitHub / Brightspace |

# %% [markdown]
# ---
# # Task 7 - Application Design Document | ILO 6.3B + 6.3C | 5 + 6 = 11 pts
# **Must pass: ILO 6.3 total > 55% (min. 9/15 pts combined with Task 8 and Task 9)**
#
# ## What to do
# **ILO 6.3B (5 pts):** Design an appropriate data storage solution that aligns with client requirements, considering security, privacy, data characteristics and access patterns. Managed through code, deployable and reproducible.
#
# **ILO 6.3C (6 pts):** Document the ETL solution - how data is extracted, transformed and loaded. The design considers deployability, scalability and reliability.
#
# - &check; Purpose and scope of the application described
# - &cross; Overall system architecture documented
# - &cross; Main components and their interactions explained
# - &cross; Database/storage design documented
# - &cross; System architecture diagram included
# - &cross; Data flow diagram included
# - &cross; Database schema diagram included
# - &cross; Design decisions and trade-offs explained (usability, reliability, maintainability, scalability, privacy, security)
# - &cross; Document reflects the design that is actually being implemented
#
# ## Evidence (per person in learning log under ILO 6.3B + C)
# | What | Where |
# |------|-------|
# | Link to the design report | GitHub / Brightspace |
# | Brief description of how you solved this task | Learning log text |

# %% [markdown]
# ---
# # Task 8 - Database Management | ILO 6.3A + 6.3B | 4 + 5 = 9 pts
# **Must pass: ILO 6.3 total > 55% (min. 9/15 pts combined with Task 7 and Task 9)**
#
# ## What to do
# **ILO 6.3A (4 pts):** Demonstrate understanding of intermediate level SQL and database fundamentals. Backend code that reads/writes to the database follows best practices.
#
# **ILO 6.3B (5 pts):** Design an appropriate data storage solution that considers security, privacy, data characteristics and access patterns. Managed through code and reproducible.
#
# - &cross; Database structure designed and created via code
# - &cross; Database creation scripts in the repository
# - &cross; Database connected to the application
# - &cross; Data structure supports the use case (historical data, features, predictions, user inputs, output results)
# - &cross; Privacy, security and reliability considered and documented (in Task 7 design document)
#
# ## Evidence (per person in learning log under ILO 6.3A + B)
# | What | Where |
# |------|-------|
# | Link to **your** backend code that interacts with the database | GitHub file URL (your commits) |
# | Brief description of how your access methods meet best practices | Learning log text |
# | Link to the database creation scripts | GitHub file URL |
# | Brief description of how the database supports the use case | Learning log text |

# %% [markdown]
# ---
# # Task 9 - Data Processing Pipelines | ILO 6.3C | 6 pts
# **Must pass: ILO 6.3 total > 55% (min. 9/15 pts combined with Task 7 and Task 8)**
#
# ## What to do
# Create a solution that can **extract** data from data sources, **transform** it (preprocessing/postprocessing) and **load** it into the storage solution. The solution is well documented, deployable, scalable and reliable.
#
# - &check; Raw data sources identified
# - &cross; Preprocessing steps implemented: cleaning, type conversion, missing values, merging, filtering, feature engineering, scaling/encoding
# - &cross; Same preprocessing applied consistently to new incoming data
# - &cross; Pipeline code is reusable and modular
# - &cross; Pipeline tested on sample or incoming data
#
# ## Evidence (per person in learning log under ILO 6.3C)
# | What | Where |
# |------|-------|
# | Link to the pipeline scripts | GitHub file URL |
# | Brief description of how you solved this task | Learning log text |

# %% [markdown]
# ---
# # Task 12 - Unit Testing and Documentation | ILO 9.2C | 4 pts
#
# ## What to do
# Develop **meaningful unit tests** to contribute to the maintainability of the codebase. Use industry standard tools to produce **professional documentation**.
#
# - &cross; Group test coverage **> 80%** (so 81% or higher)
# - &cross; Coverage report generated and accessible
# - &cross; Everyone has authored at least one unit test (provable via GitHub commit history)
# - &cross; Everyone can execute unit tests locally
# - &cross; README and/or Sphinx documentation completed
#
# ## Evidence (per person in learning log under ILO 9.2C)
# | What | Where |
# |------|-------|
# | Link to **your** unit tests | GitHub file URL (your commits) |
# | Link to the group coverage report | GitHub URL |
# | Link to the documentation (README or Sphinx) | GitHub URL |

# %% [markdown]
# ---
# # Task 13 - Application Development | ILO 9.2D | 4 pts
#
# ## What to do
# Produce a **proof of concept application or dashboard** to present the solution in a user-friendly manner to non-technical stakeholders.
#
# - &cross; Working application or dashboard built
# - &cross; Application follows good UX principles
# - &cross; Visualisations included that convey insights, predictions and strategic advice
# - &cross; Docker or Docker Compose files created
# - &cross; Build and run instructions documented in README
# - &cross; Application demonstrated in final presentation
#
# ## Evidence (per person in learning log under ILO 9.2D)
# | What | Where |
# |------|-------|
# | Link to Docker or Docker Compose files | GitHub file URL |
# | Link to README or documentation explaining how to run the app | GitHub URL |
# | Brief description of how the team solved this task | Learning log text |

# %% [markdown]
# ---
# # Task 14 - Final Presentation | ILO 4.2C | 5 pts
# **Must pass: ILO 4.2 total > 55% (min. 6/10 pts combined with Task 5 and Task 6)**
#
# ## What to do
# Present the project outcomes, highlighting the **value for the client**, addressing **business value**, in a **well-structured and clear** manner for both technical and non-technical audiences.
#
# - &cross; All team members present
# - &cross; Application demonstrated live
# - &cross; Problem, approach, results and business value explained
# - &cross; Presentation understandable for both technical and non-technical audience
#
# ## Evidence (per person in learning log under ILO 4.2C)
# | What | Where |
# |------|-------|
# | Link to presentation media (slides, demo, etc.) | GitHub / OneDrive |
# | Brief description of how you approached and completed this task | Learning log text |

# %% [markdown]
# ---
# # Status Overview
#
# | Task | ILO | Points | Must Pass | Done |
# |------|-----|--------|-----------|------|
# | 2 | 9.2A | 2 | No | &cross; |
# | 4.2 | 3.3B | 3 | > 55% ILO 3.3 (min. 6/10) | &cross; |
# | 6 | 4.2B | 3 | > 55% ILO 4.2 (min. 6/10) | &cross; |
# | 7 | 6.3B + C | 11 | > 55% ILO 6.3 (min. 9/15) | &cross; |
# | 8 | 6.3A + B | 9 | > 55% ILO 6.3 (min. 9/15) | &cross; |
# | 9 | 6.3C | 6 | > 55% ILO 6.3 (min. 9/15) | &cross; |
# | 12 | 9.2C | 4 | No | &cross; |
# | 13 | 9.2D | 4 | No | &cross; |
# | 14 | 4.2C | 5 | > 55% ILO 4.2 (min. 6/10) | &cross; |
